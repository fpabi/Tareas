# %% [markdown]
# <a href="https://colab.research.google.com/github/fpabi/Tareas/blob/main/Tarea_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)

# %%
import numpy as np

# %%
data = np.genfromtxt('datos_olas.csv', delimiter=',', skip_header=1, dtype=None, encoding=None)

# %%
print(data)
# Out:
# [('A', '2022-11-25', 4.87846407) ('A', '2023-03-03', 0.32100211)
#  ('D', '2022-09-22', 9.66505196) ('D', '2023-05-22', 2.06802943)
#  ('E', '2022-11-09', 8.64743269) ('D', '2023-03-27', 1.06894673)
#  ('D', '2023-05-18', 5.77223335) ('A', '2022-10-10', 5.43816497)
#  ('B', '2023-05-08', 3.38164145) ('E', '2023-01-31', 8.76214502)
#  ('D', '2023-04-27', 6.96088407) ('D', '2022-09-28', 7.88082663)
#  ('C', '2023-03-10', 6.33768938) ('E', '2023-05-25', 3.58551699)
#  ('B', '2023-02-24', 8.04451408) ('A', '2023-03-18', 9.15816324)
#  ('A', '2023-01-24', 2.13039671) ('B', '2023-05-01', 7.61968527)
#  ('D', '2022-12-04', 5.00819467) ('C', '2023-03-11', 6.37610633)
#  ('D', '2023-04-27', 8.9881659 ) ('C', '2022-12-06', 1.70137878)
#  ('A', '2023-04-03', 1.96649351) ('A', '2022-07-15', 4.67404529)
#  ('A', '2022-11-10', 4.52179454) ('C', '2022-12-26', 0.36118524)
#  ('A', '2023-02-23', 9.30103056) ('E', '2022-08-19', 0.8744858 )
#  ('E', '2023-06-02', 3.85608113) ('A', '2022-09-03', 9.34172845)
#  ('A', '2022-08-09', 2.94161329) ('D', '2023-02-05', 4.10572062)
#  ('A', '2023-04-13', 2.38798363) ('A', '2022-07-14', 1.50692247)
#  ('B', '2023-01-24', 3.72435097) ('D', '2022-09-05', 0.89682111)
#  ('E', '2022-09-07', 7.24512516) ('D', '2022-12-31', 9.8232728 )
#  ('D', '2022-12-28', 2.92417257) ('A', '2023-02-26', 1.26318852)
#  ('C', '2023-01-11', 6.71030984) ('D', '2022-12-29', 0.15471541)
#  ('A', '2022-08-06', 0.34886137) ('C', '2023-05-10', 4.04010562)
#  ('C', '2022-12-07', 9.97729349) ('C', '2023-01-16', 3.26750884)
#  ('A', '2022-09-18', 1.65166459) ('D', '2023-06-17', 8.273038  )
#  ('C', '2023-01-14', 1.92433762) ('C', '2023-02-12', 8.63080405)
#  ('C', '2023-05-05', 6.37591022) ('A', '2022-08-03', 8.28376454)
#  ('C', '2023-04-19', 2.53633869) ('B', '2023-05-07', 7.12911371)
#  ('B', '2023-06-11', 1.7874111 ) ('A', '2022-08-22', 0.58673902)
#  ('C', '2023-04-12', 2.59805142) ('B', '2022-09-09', 4.02955131)
#  ('E', '2022-08-03', 5.98578425) ('D', '2022-12-19', 4.0273011 )
#  ('C', '2023-05-24', 8.64441421) ('D', '2022-08-15', 9.87457455)
#  ('A', '2023-02-10', 4.34168313) ('A', '2022-11-29', 1.81043761)
#  ('E', '2023-03-15', 9.41294896) ('C', '2022-10-26', 0.33557212)
#  ('A', '2023-03-17', 7.96428109) ('E', '2023-04-22', 5.29567959)
#  ('B', '2023-02-15', 6.03024126) ('C', '2023-06-21', 9.41816043)
#  ('C', '2022-10-18', 3.19682152) ('D', '2023-01-06', 1.42667961)
#  ('C', '2022-12-12', 7.02214669) ('D', '2022-09-02', 9.33762327)
#  ('B', '2023-06-14', 3.67891574) ('A', '2023-06-29', 2.95519895)
#  ('D', '2023-06-17', 0.03941384) ('A', '2022-10-17', 7.65294224)
#  ('A', '2023-06-17', 5.02642205) ('E', '2023-05-04', 8.72841157)
#  ('D', '2023-04-27', 9.64399382) ('B', '2022-11-04', 3.32370131)
#  ('A', '2022-09-06', 7.40063791) ('D', '2023-01-14', 1.12339274)
#  ('E', '2023-05-19', 9.14553084) ('A', '2022-10-21', 6.89500539)
#  ('E', '2023-06-20', 0.48677188) ('C', '2023-03-20', 9.00809713)
#  ('D', '2023-06-05', 7.50671124) ('E', '2022-07-24', 6.8890535 )
#  ('A', '2022-10-19', 5.79689814) ('D', '2023-04-04', 2.36068336)
#  ('C', '2022-08-07', 7.47281784) ('B', '2022-10-21', 3.17057082)
#  ('E', '2023-05-10', 6.32382801) ('C', '2022-09-23', 0.29182095)
#  ('A', '2023-04-01', 9.3015302 ) ('C', '2022-11-24', 1.18556257)
#  ('D', '2023-03-19', 8.37876698) ('A', '2022-07-26', 4.55242957)]
