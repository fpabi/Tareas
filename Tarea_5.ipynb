# %% [markdown]
# <a href="https://colab.research.google.com/github/fpabi/Tareas/blob/main/Tarea_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
import numpy as np

# %%
#Se carga a data el contenido del archivo datos_olas.cvs
data = np.genfromtxt('datos_olas.csv', delimiter=',', dtype=str, skip_header=1)#(nombre del archivo,separado por comas,el tipo de datos de cada columa lo lee como un str, se salta la fima 1 que es de encabezado)

#se verifica que se haya ingresado correctamente la informacion
print(data)
# Out:
# [['A' '2022-11-25' '4.878464067401625']
#  ['A' '2023-03-03' '0.3210021110900163']
#  ['D' '2022-09-22' '9.665051956287837']
#  ['D' '2023-05-22' '2.0680294339172933']
#  ['E' '2022-11-09' '8.647432687107191']
#  ['D' '2023-03-27' '1.0689467329471025']
#  ['D' '2023-05-18' '5.772233348630593']
#  ['A' '2022-10-10' '5.438164968887866']
#  ['B' '2023-05-08' '3.3816414491719025']
#  ['E' '2023-01-31' '8.762145016520346']
#  ['D' '2023-04-27' '6.960884071578922']
#  ['D' '2022-09-28' '7.880826626274074']
#  ['C' '2023-03-10' '6.33768938022759']
#  ['E' '2023-05-25' '3.5855169916685914']
#  ['B' '2023-02-24' '8.04451407658844']
#  ['A' '2023-03-18' '9.15816323638438']
#  ['A' '2023-01-24' '2.130396710979121']
#  ['B' '2023-05-01' '7.619685271566826']
#  ['D' '2022-12-04' '5.008194672538981']
#  ['C' '2023-03-11' '6.376106329916516']
#  ['D' '2023-04-27' '8.98816589845325']
#  ['C' '2022-12-06' '1.7013787830619964']
#  ['A' '2023-04-03' '1.9664935094620795']
# ...

# %%
# Crear diccionarios para almacenar la suma y el contador de alturas por zona
suma_alturas_por_zona = {}
contador_alturas_por_zona = {}

# Iterar sobre los datos y acumular la suma y el contador por zona
for row in data:
    zona = row[0]                     # Obtener la zona de la primera columna
    altura = float(row[2])            # Convertir la altura a un número decimal porque esta en formato de str
    if zona in suma_alturas_por_zona:
        suma_alturas_por_zona[zona] += altura
        contador_alturas_por_zona[zona] += 1
    else:
        suma_alturas_por_zona[zona] = altura
        contador_alturas_por_zona[zona] = 1
